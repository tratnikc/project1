# %%
# Import dependencies
import os 
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
import requests

# %%
# Data Files
vancouver_01_path = os.path.join("resources/Mobi_System_Data_2019-01.csv")
vancouver_02_path = os.path.join("resources/Mobi_System_Data_2019-02.csv")
vancouver_03_path = os.path.join("resources/Mobi_System_Data_2019-03.csv")
vancouver_04_path = os.path.join("resources/Mobi_System_Data_2019-04.csv")
vancouver_05_path = os.path.join("resources/Mobi_System_Data_2019-05.csv")
vancouver_06_path = os.path.join("resources/Mobi_System_Data_2019-06.csv")
vancouver_07_path = os.path.join("resources/Mobi_System_Data_2019-07.csv")
vancouver_08_path = os.path.join("resources/Mobi_System_Data_2019-08.csv")
vancouver_09_path = os.path.join("resources/Mobi_System_Data_2019-09.csv")
vancouver_10_path = os.path.join("resources/Mobi_System_Data_2019-10.csv")
vancouver_11_path = os.path.join("resources/Mobi_System_Data_2019-11.csv")
vancouver_12_path = os.path.join("resources/Mobi_System_Data_2019-12.csv")

# Read Data Files 
vancouver_01 = pd.read_csv(vancouver_01_path, encoding="utf=8")
vancouver_02 = pd.read_csv(vancouver_02_path, encoding="utf=8")
vancouver_03 = pd.read_csv(vancouver_03_path, encoding="utf=8")
vancouver_04 = pd.read_csv(vancouver_04_path, encoding="utf=8")
vancouver_05 = pd.read_csv(vancouver_05_path, encoding="utf=8")
vancouver_06 = pd.read_csv(vancouver_06_path, encoding="utf=8")
vancouver_07 = pd.read_csv(vancouver_07_path, encoding="utf=8")
vancouver_08 = pd.read_csv(vancouver_08_path, encoding="utf=8")
vancouver_09 = pd.read_csv(vancouver_09_path, encoding="utf=8")
vancouver_10 = pd.read_csv(vancouver_10_path, encoding="utf=8")
vancouver_11 = pd.read_csv(vancouver_11_path, encoding="utf=8")
vancouver_12 = pd.read_csv(vancouver_12_path, encoding="utf=8")

# Combine Data into Quarters (Q1. Q2, Q3, Q4)
q1 = pd.concat([vancouver_01, vancouver_02, vancouver_03], ignore_index=True)
q2 = pd.concat([vancouver_04, vancouver_05, vancouver_06], ignore_index=True)
q3 = pd.concat([vancouver_07, vancouver_08, vancouver_09], ignore_index=True)
q4 = pd.concat([vancouver_10, vancouver_11, vancouver_12], ignore_index=True)

# %%
# Display Data Table for Preview - Q1
q1
# Out:
#               Departure         Return    Bike        Departure station  \
# 0         2/1/2019 0:00  2/1/2019 0:00   388.0          0198 6th & Main
# 1         2/1/2019 0:00  2/1/2019 0:00  1880.0       0193 Science World
# 2         2/1/2019 0:00  2/1/2019 0:00   779.0  0063 Robson & Granville
# 3         2/1/2019 0:00  2/1/2019 0:00  2123.0       0064 Expo & Smithe
# 4       1/31/2019 23:00  2/1/2019 0:00   444.0   0060 Bidwell & Burnaby
# ...                 ...            ...     ...                      ...
# 120307    4/1/2019 0:00  4/1/2019 0:00  1063.0        0119 3rd & Quebec
# 120308    4/1/2019 0:00  4/1/2019 1:00  1067.0        0050 Bute & Comox
# 120309    4/1/2019 0:00  4/1/2019 1:00  1016.0     0096 Nicola & Robson
# 120310    4/1/2019 0:00  4/1/2019 0:00   786.0     0002 Burrard Station
# 120311    4/1/2019 0:00  4/1/2019 0:00    37.0        0119 3rd & Quebec
#
#                         Return station             Membership type  \
# ...

# %%
# Display Data Table for Preview - Q2
q2
# Out:
#             Departure         Return    Bike        Departure station  \
# 0       4/30/19 23:51  4/30/19 23:57   179.0  0039 Helmcken & Burrard
# 1       4/30/19 23:47  4/30/19 23:50   961.0        0187 Bute & Davie
# 2       4/30/19 23:45    5/1/19 0:39   834.0   0125 Hamilton & Robson
# 3       4/30/19 23:42  4/30/19 23:50  1535.0  0044 Pacific & Richards
# 4       4/30/19 23:39  4/30/19 23:49   307.0       0028 Davie & Beach
# ...               ...            ...     ...                      ...
# 261535  7/1/2019 0:00  7/1/2019 0:00   730.0        0177 Quebec & 1st
# 261536  7/1/2019 0:00  7/1/2019 0:00  1186.0         0255 18th & Main
# 261537  7/1/2019 0:00  7/1/2019 0:00   458.0       0110 5th & Arbutus
# 261538  7/1/2019 0:00  7/1/2019 0:00  2161.0  0126 Thurlow & Pendrell
# 261539  7/1/2019 0:00  7/1/2019 0:00   961.0         0255 18th & Main
#
#                    Return station             Membership type  \
# 0             0032 Comox & Denman   365 Day Founding Standard
# ...

# %%
# Display Data Table for Preview - Q3
q3
# Out:
#               Departure           Return    Bike         Departure station  \
# 0         8/1/2019 0:00    8/1/2019 0:00   244.0    0060 Bidwell & Burnaby
# 1         8/1/2019 0:00    8/1/2019 0:00  1278.0       0088 Harwood & Bute
# 2         8/1/2019 0:00    8/1/2019 0:00   296.0      0027 Beatty & Nelson
# 3         8/1/2019 0:00    8/1/2019 0:00  1700.0      0027 Beatty & Nelson
# 4         8/1/2019 0:00    8/1/2019 0:00   414.0     0207 Alberni & Jervis
# ...                 ...              ...     ...                       ...
# 357566  2019-09-01 0:00  2019-09-01 1:00  1900.0        0064 Expo & Smithe
# 357567  2019-09-01 0:00  2019-09-01 0:00  2034.0     0071 14th & Granville
# 357568  2019-09-01 0:00  2019-09-01 0:00   365.0      0002 Burrard Station
# 357569  2019-09-01 0:00  2019-09-01 0:00  1076.0   0040 Cardero & Pendrell
# 357570  2019-09-01 0:00  2019-09-01 0:00   769.0  0021 Cordova & Granville
#
# ...

# %%
# Display Data Table for Preview - Q4
q4
# Out:
#               Departure           Return    Bike  \
# 0       2019-11-01 0:00  2019-11-01 0:00  1464.0
# 1       2019-11-01 0:00  2019-11-01 0:00   589.0
# 2       2019-11-01 0:00  2019-11-01 0:00   217.0
# 3       2019-11-01 0:00  2019-11-01 0:00   391.0
# 4       2019-11-01 0:00  2019-11-01 0:00  1692.0
# ...                 ...              ...     ...
# 152338  2019-12-01 0:00  2019-12-01 0:00   631.0
# 152339  2019-12-01 0:00  2019-12-01 1:00  1394.0
# 152340  2019-12-01 0:00  2019-12-01 0:00  1511.0
# 152341  2019-12-01 0:00  2019-12-01 0:00   985.0
# 152342  2019-12-01 0:00  2019-12-01 0:00   291.0
#
#                                Departure station  \
# 0               0004 Yaletown-Roundhouse Station
# 1               0004 Yaletown-Roundhouse Station
# 2               0004 Yaletown-Roundhouse Station
# 3       0099 Vancouver Art Gallery - North Plaza
# 4                              0177 Quebec & 1st
# ...                                          ...
# ...

# %%
# Summary Metrics Data Frame
# Total Trips
q1_total = q1.count()["Bike"]
q2_total = q2.count()["Bike"]
q3_total = q3.count()["Bike"]
q4_total = q4.count()["Bike"]

total_trips = q1_total + q2_total + q3_total + q4_total
total_trips

print(q1_total, q2_total, q3_total, q4_total, total_trips)
# Out:
# 120308 261536 357251 152139 891234

# %%
# Summary Metrics Data Frame
# Station IDs in Q1
q1_uniq_start = q1["Departure station"].nunique() 
q1_uniq_start
q1_uniq_end= q1["Return station"].nunique()
q1_uniq_end
# Out:
# 186

# %%
# Station IDs in Q2
q2_uniq_start = q2["Departure station"].nunique() 
q2_uniq_end= q2["Return station"].nunique()
q2_uniq_start
q2_uniq_end
# Out:
# 196

# %%
# Station IDs in Q3
q3_uniq_start = q3["Departure station"].nunique() 
q3_uniq_end= q3["Return station"].nunique()
q3_uniq_start
q3_uniq_end
# Out:
# 203

# %%
# Station IDs in Q4
q4_uniq_start = q4["Departure station"].nunique() 
q4_uniq_end= q4["Return station"].nunique()
q4_uniq_start
q4_uniq_end
# Out:
# 208

# %%
# Summary Metrics Data Frame
# All Station IDs in Q1

q1_start_stn = q1["Departure station"]
q1_end_stn = q1["Return station"]
vancouver_stations = []

# %%
# Total Unique Stations in Q1
for x in range(len(q1)):
    station = q1_start_stn[x]
    if station not in vancouver_stations:
        vancouver_stations.append(station)

for x in range(len(q1)):
    station = q1_end_stn[x]
    if station not in vancouver_stations:
        vancouver_stations.append(station)

# %%
len(vancouver_stations)
# Out:
# 187

# %%
# All Station IDs in Q2 (blocked until above error code is resolved)

q2_start_stn = q2["Departure station"]
q2_end_stn = q2["Return station"]
vancouver_stations = []

# %%
# Total Unique Stations in Q2
for x in range(len(q2)):
    station = q2_start_stn[x]
    if station not in vancouver_stations:
        vancouver_stations.append(station)

for x in range(len(q2)):
    station = q2_end_stn[x]
    if station not in vancouver_stations:
        vancouver_stations.append(station)

# %%
len(vancouver_stations)
# Out:
# 197

# %%
# All Station IDs in Q3 (blocked until above error code is resolved)

q3_start_stn = q3["Departure station"]
q3_end_stn = q3["Return station"]
vancouver_stations = []

# %%
# Total Unique Stations in Q3
for x in range(len(q3)):
    station = q3_start_stn[x]
    if station not in vancouver_stations:
        vancouver_stations.append(station)

for x in range(len(q3)):
    station = q3_end_stn[x]
    if station not in vancouver_stations:
        vancouver_stations.append(station)

# %%
len(vancouver_stations)
# Out:
# 205

# %%
# All Station IDs in Q4 (blocked until above error code is resolved)

q4_start_stn = q4["Departure station"]
q4_end_stn = q4["Return station"]
vancouver_stations = []

# %%
# Total Unique Stations in Q4     
for x in range(len(q4)):
    station = q4_start_stn[x]
    if station not in vancouver_stations:
        vancouver_stations.append(station)

for x in range(len(q4)):
    station = q4_end_stn[x]
    if station not in vancouver_stations:
        vancouver_stations.append(station)

# %%
len(vancouver_stations)
# Out:
# 209

# %%
# Summary Metrics Data Frame
# Total Number of Subscription Users in Q1, Q2, Q3, Q3, Q4

# Only data availble is the "Membership type" column. 
#There is no separate data like the toronto dataset

# %%
# Summary Metrics Data Frame
# Total Number fo Casual vs. Annual Members (usertype) 
# in Q1, Q2, Q3, Q3, Q4
user_type = q1[["Membership type"]].drop_duplicates()
user_type_df = pd.DataFrame({"Total Count" : user_type["Membership type"].value_counts()})
user_type_df

user_type = q2[["Membership type"]].drop_duplicates()
user_type_df = pd.DataFrame({"Total Count" : user_type["Membership type"].value_counts()})
user_type_df

user_type = q3[["Membership type"]].drop_duplicates()
user_type_df = pd.DataFrame({"Total Count" : user_type["Membership type"].value_counts()})
user_type_df

user_type = q4[["Membership type"]].drop_duplicates()
user_type_df = pd.DataFrame({"Total Count" : user_type["Membership type"].value_counts()})
user_type_df
# Out:
#                                 Total Count
# Archived Monthly Standard                 1
# Archived Monthly Basic                    1
# 365 Corporate Standard                    1
# Archived Monthly Plus                     1
# 365 Corporate Plus Renewal                1
# Shared Mobility Pass                      1
# 24 Hour                                   1
# 365 Corporate Plus                        1
# 365 Plus                                  1
# 365 Day Founding Plus                     1
# 30 Day Pass                               1
# VIP                                       1
# 365 Corporate Standard Renewal            1
# 365 Day Founding Standard                 1
# Vancity Community Pass                    1
# 365 Day Pass Plus SALE                    1
# Archived 90 Day                           1
# 365 Day Pass Standard SALE                1
# 365 Standard                              1

# %%
# Summary Metrics Data Frame
# Average Trip Duration in Q1, Q2, Q3, Q3, Q4
trip_duration = q1["Duration (sec.)"].mean()
avg_trip_duration = trip_duration / 60

# %%
q1
# Out:
#               Departure         Return    Bike        Departure station  \
# 0         2/1/2019 0:00  2/1/2019 0:00   388.0          0198 6th & Main
# 1         2/1/2019 0:00  2/1/2019 0:00  1880.0       0193 Science World
# 2         2/1/2019 0:00  2/1/2019 0:00   779.0  0063 Robson & Granville
# 3         2/1/2019 0:00  2/1/2019 0:00  2123.0       0064 Expo & Smithe
# 4       1/31/2019 23:00  2/1/2019 0:00   444.0   0060 Bidwell & Burnaby
# ...                 ...            ...     ...                      ...
# 120307    4/1/2019 0:00  4/1/2019 0:00  1063.0        0119 3rd & Quebec
# 120308    4/1/2019 0:00  4/1/2019 1:00  1067.0        0050 Bute & Comox
# 120309    4/1/2019 0:00  4/1/2019 1:00  1016.0     0096 Nicola & Robson
# 120310    4/1/2019 0:00  4/1/2019 0:00   786.0     0002 Burrard Station
# 120311    4/1/2019 0:00  4/1/2019 0:00    37.0        0119 3rd & Quebec
#
#                         Return station             Membership type  \
# ...

# %%
trip_duration = q2["Duration (sec.)"].mean()
avg_trip_duration = trip_duration / 60

# %%
q2
# Out:
#             Departure         Return    Bike        Departure station  \
# 0       4/30/19 23:51  4/30/19 23:57   179.0  0039 Helmcken & Burrard
# 1       4/30/19 23:47  4/30/19 23:50   961.0        0187 Bute & Davie
# 2       4/30/19 23:45    5/1/19 0:39   834.0   0125 Hamilton & Robson
# 3       4/30/19 23:42  4/30/19 23:50  1535.0  0044 Pacific & Richards
# 4       4/30/19 23:39  4/30/19 23:49   307.0       0028 Davie & Beach
# ...               ...            ...     ...                      ...
# 261535  7/1/2019 0:00  7/1/2019 0:00   730.0        0177 Quebec & 1st
# 261536  7/1/2019 0:00  7/1/2019 0:00  1186.0         0255 18th & Main
# 261537  7/1/2019 0:00  7/1/2019 0:00   458.0       0110 5th & Arbutus
# 261538  7/1/2019 0:00  7/1/2019 0:00  2161.0  0126 Thurlow & Pendrell
# 261539  7/1/2019 0:00  7/1/2019 0:00   961.0         0255 18th & Main
#
#                    Return station             Membership type  \
# 0             0032 Comox & Denman   365 Day Founding Standard
# ...

# %%
trip_duration = q3["Duration (sec.)"].mean()
avg_trip_duration = trip_duration / 60

# %%
q3
# Out:
#               Departure           Return    Bike         Departure station  \
# 0         8/1/2019 0:00    8/1/2019 0:00   244.0    0060 Bidwell & Burnaby
# 1         8/1/2019 0:00    8/1/2019 0:00  1278.0       0088 Harwood & Bute
# 2         8/1/2019 0:00    8/1/2019 0:00   296.0      0027 Beatty & Nelson
# 3         8/1/2019 0:00    8/1/2019 0:00  1700.0      0027 Beatty & Nelson
# 4         8/1/2019 0:00    8/1/2019 0:00   414.0     0207 Alberni & Jervis
# ...                 ...              ...     ...                       ...
# 357566  2019-09-01 0:00  2019-09-01 1:00  1900.0        0064 Expo & Smithe
# 357567  2019-09-01 0:00  2019-09-01 0:00  2034.0     0071 14th & Granville
# 357568  2019-09-01 0:00  2019-09-01 0:00   365.0      0002 Burrard Station
# 357569  2019-09-01 0:00  2019-09-01 0:00  1076.0   0040 Cardero & Pendrell
# 357570  2019-09-01 0:00  2019-09-01 0:00   769.0  0021 Cordova & Granville
#
# ...

# %%
trip_duration = q4["Duration (sec.)"].mean()
avg_trip_duration = trip_duration / 60

# %%
q4
# Out:
#               Departure           Return    Bike  \
# 0       2019-11-01 0:00  2019-11-01 0:00  1464.0
# 1       2019-11-01 0:00  2019-11-01 0:00   589.0
# 2       2019-11-01 0:00  2019-11-01 0:00   217.0
# 3       2019-11-01 0:00  2019-11-01 0:00   391.0
# 4       2019-11-01 0:00  2019-11-01 0:00  1692.0
# ...                 ...              ...     ...
# 152338  2019-12-01 0:00  2019-12-01 0:00   631.0
# 152339  2019-12-01 0:00  2019-12-01 1:00  1394.0
# 152340  2019-12-01 0:00  2019-12-01 0:00  1511.0
# 152341  2019-12-01 0:00  2019-12-01 0:00   985.0
# 152342  2019-12-01 0:00  2019-12-01 0:00   291.0
#
#                                Departure station  \
# 0               0004 Yaletown-Roundhouse Station
# 1               0004 Yaletown-Roundhouse Station
# 2               0004 Yaletown-Roundhouse Station
# 3       0099 Vancouver Art Gallery - North Plaza
# 4                              0177 Quebec & 1st
# ...                                          ...
# ...

# %%
# Summary Metrics Data Frame
# Bins (Max & Min) in Q1, Q2, Q3, Q3, Q4

# i am not too confident with this, 
#so if its alright can we do this together
